# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

diabetes=datasets.load_diabetes()
x=diabetes.data
y=diabetes.target

x2=sm.add_constant(x)
est=sm.OLS(y,x2)
est2=est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     46.27
# Date:                Mon, 24 Feb 2020   Prob (F-statistic):           3.83e-62
# Time:                        10:35:07   Log-Likelihood:                -2386.0
# No. Observations:                 442   AIC:                             4794.
# Df Residuals:                     431   BIC:                             4839.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        152.1335      2.576     59.061      0.000     147.071     157.196
# ...

# %%
df=pd.read_csv('HR_Comma_Sep.csv')
df.shape
## drop department columns
#create dummy variables for salary
subdf=df.drop(['sales','last_evaluation','number_project'], axis=1)
subdf
subdf2=pd.get_dummies(subdf, prefix='salary', drop_first=True)
subdf2
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  \
# 0                    0.38                   157                   3
# 1                    0.80                   262                   6
# 2                    0.11                   272                   4
# 3                    0.72                   223                   5
# 4                    0.37                   159                   3
# ...                   ...                   ...                 ...
# 14994                0.40                   151                   3
# 14995                0.37                   160                   3
# 14996                0.37                   143                   3
# 14997                0.11                   280                   4
# 14998                0.37                   158                   3
#
#        Work_accident  left  promotion_last_5years  salary_low  salary_medium
# ...

# %%
from sklearn.model_selection import train_test_split
x=subdf2.drop('left', axis=1)

y=subdf2.left
train_x, test_x, train_y, test_y=train_test_split(x, y, test_size=0.33, random_state=42)

# %%
train_x2=sm.add_constant(train_x)
ols=sm.OLS(train_y,train_x2)
ols2=ols.fit()
print(ols2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   left   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     387.4
# Date:                Mon, 24 Feb 2020   Prob (F-statistic):               0.00
# Time:                        10:45:09   Log-Likelihood:                -4477.0
# No. Observations:               10049   AIC:                             8970.
# Df Residuals:                   10041   BIC:                             9028.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.2827      0.024     11.666      0.000       0.235       0.330
# ...

# %%
train_x2=sm.add_constant(train_x)
logit=sm.Logit(train_y,train_x2)
logit2=logit.fit()
print(logit2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.433479
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                   left   No. Observations:                10049
# Model:                          Logit   Df Residuals:                    10041
# Method:                           MLE   Df Model:                            7
# Date:                Mon, 24 Feb 2020   Pseudo R-squ.:                  0.2098
# Time:                        10:57:38   Log-Likelihood:                -4356.0
# converged:                       True   LL-Null:                       -5512.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...
